# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [02:12, 236kB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
### Your code here
from collections import Counter
import random

threshold = 0.00001

word_counts = Counter(int_words)
total = len(int_words)

frequencies = {word: count / total for word, count in word_counts.items()}
drop_prob = {word: 1 - np.sqrt(threshold / frequencies[word]) for word in word_counts}

# Chec
train_words = [word for word in int_words if (1 - drop_prob[word]) > random.random()]

# %% [markdown]
# [Read this](https://discussions.udacity.com/t/skip-gram-exercices/228142) to understand why `random.random()` was used to determine which words to keep in the code above.

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, index, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    ### Your code here
    r = np.random.randint(1, window_size + 1)
    
    start = index - r if (index - r) > 0 else 0
    stop = index + r
    
    target_words = set(words[start:index] + words[(index + 1):(stop + 1)])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    # create embedding weight matrix here
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))
    # use tf.nn.embedding_lookup to get the hidden layer output
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    # create softmax weight matrix here
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    # create softmax biases here
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, 
                                      embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keepdims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6445 0.0558 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6239 0.0391 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.4956 0.0381 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.6116 0.0377 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5406 0.0380 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5195 0.0384 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5551 0.0393 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5512 0.0387 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4785 0.0400 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4438 0.0381 sec/batch
# Nearest to one: convert, moritz, matchbox, six, human, recursion, sapphic, precise,
# Nearest to about: harmonization, image, federer, suitcases, covert, overthrow, displayed, appliances,
# Nearest to with: beekeepers, schreiber, vertigo, silkworm, spars, guppies, campaign, coincidental,
# Nearest to will: disorganized, purport, ruston, pelle, don, burghs, brittle, andromeda,
# Nearest to and: flashes, readability, eats, triiodothyronine, parlance, plaine, seclusion, hydrozoa,
# Nearest to than: gorham, thieves, invited, anthrax, patriarchal, slag, waltham, ifconfig,
# Nearest to it: ql, consonantal, corral, mindat, theater, cathinone, settings, peacock,
# Nearest to they: fisher, port, parked, shipmates, hy, anthemius, coach, prakash,
# Nearest to brother: apparel, ferdinando, hier, dojo, indulge, haihowak, paladins, incumbents,
# Nearest to governor: michiel, corpses, conservatively, centerline, locations, manna, prevailing, gunung,
# Nearest to primarily: aas, suitcases, revivals, aps, time, bloemfontein, magnet, hannity,
# Nearest to resources: hideo, topple, brocklin, fictions, alois, grandparents, thabo, ethnographers,
# Nearest to quite: salic, sunshine, bibl, anomie, shinogi, cavour, vapors, jeannie,
# Nearest to hit: sheikh, hinder, limits, widdecombe, emitted, encomium, ration, streaming,
# Nearest to gold: breaking, squarepants, fallingwater, houllier, discussions, dine, ochs, strictly,
# Nearest to consists: maji, assiniboine, changed, darkening, samuel, japheth, preu, threatened,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.5012 0.0400 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3743 0.0390 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3047 0.0381 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2410 0.0383 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1738 0.0385 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1529 0.0393 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1360 0.0385 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0861 0.0394 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0005 0.0380 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9954 0.0387 sec/batch
# Nearest to one: convert, pro, human, six, precise, indicates, moritz, th,
# Nearest to about: image, displayed, overthrow, views, covert, established, also, federer,
# Nearest to with: beekeepers, campaign, organized, guppies, spars, helps, secretary, closed,
# Nearest to will: don, purport, disorganized, half, replaced, andromeda, dimension, recently,
# Nearest to and: earliest, class, eats, masturbation, simulate, proved, revenues, drawn,
# Nearest to than: invited, thieves, members, patriarchal, republic, anthrax, selects, slag,
# Nearest to it: settings, theater, site, marry, consonantal, a, onto, corral,
# Nearest to they: port, fisher, parked, coach, shipmates, oak, casuistry, hy,
# Nearest to brother: apparel, ferdinando, haihowak, paladins, hier, karnataka, indulge, lucien,
# Nearest to governor: locations, corpses, well, conservatively, centerline, prevailing, michiel, gunung,
# Nearest to primarily: time, aps, suitcases, idea, revivals, previous, bloemfontein, aas,
# Nearest to resources: hideo, grandparents, fictions, counselling, brocklin, topple, grid, coast,
# Nearest to quite: sunshine, bibl, admiral, anomie, industrialization, bce, follows, vegetation,
# Nearest to hit: limits, sheikh, happened, widdecombe, spain, hinder, emitted, streaming,
# Nearest to gold: breaking, discussions, squarepants, strictly, fallingwater, dine, houllier, necessity,
# Nearest to consists: changed, assiniboine, suggest, samuel, maji, stick, faces, translate,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9503 0.0386 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9070 0.0396 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8780 0.0386 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8680 0.0391 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8089 0.0408 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8168 0.0385 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7911 0.0393 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.8147 0.0397 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7955 0.0381 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7730 0.0394 sec/batch
# Nearest to one: six, pro, moritz, th, convert, mes, matchbox, uprising,
# Nearest to about: covert, overthrow, displayed, image, harmonization, appliances, cilicia, blanket,
# Nearest to with: beekeepers, guppies, vertigo, spars, coincidental, helps, closed, refraining,
# Nearest to will: don, purport, disorganized, owed, andromeda, devices, banquet, decoration,
# Nearest to and: earliest, imperfect, phenomena, readability, masturbation, proved, seclusion, simulate,
# Nearest to than: thieves, invited, patriarchal, anthrax, detonation, selects, gorham, constitutional,
# Nearest to it: settings, theater, marry, subatomic, observance, consonantal, something, a,
# Nearest to they: port, parked, fisher, hy, shipmates, penchant, characteristics, crimean,
# Nearest to brother: apparel, ferdinando, haihowak, paladins, karnataka, widow, hier, lucien,
# Nearest to governor: locations, corpses, prevailing, centerline, well, conservatively, steamy, gunung,
# Nearest to primarily: time, revivals, suitcases, aps, magnet, bloemfontein, idea, previous,
# Nearest to resources: hideo, grandparents, fictions, lords, coast, grid, brocklin, topple,
# Nearest to quite: sunshine, admiral, bibl, bce, breslau, salic, adding, industrialization,
# Nearest to hit: hinder, sheikh, limits, streaming, emitted, spain, ration, encomium,
# Nearest to gold: breaking, squarepants, discussions, strictly, fallingwater, dine, trademark, shipments,
# Nearest to consists: changed, assiniboine, threatened, faces, maji, irritation, stick, samuel,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7841 0.0401 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7389 0.0390 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7106 0.0387 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7203 0.0393 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7113 0.0381 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6598 0.0384 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.6876 0.0388 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7306 0.0377 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.6955 0.0397 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6714 0.0394 sec/batch
# Nearest to one: six, pro, zero, moritz, five, mes, th, dribble,
# Nearest to about: covert, overthrow, harmonization, displayed, image, federer, blanket, appliances,
# Nearest to with: beekeepers, guppies, spars, faithless, coincidental, silkworm, refraining, vertigo,
# Nearest to will: don, purport, disenchanted, warhammer, disorganized, redoutable, decoration, devices,
# Nearest to and: earliest, masturbation, enchanted, sacrifices, readability, phenomena, proved, imperfect,
# Nearest to than: thieves, invited, patriarchal, detonation, anthrax, gorham, slag, waltham,
# Nearest to it: settings, marry, consonantal, either, something, subatomic, a, peacock,
# Nearest to they: parked, hy, port, fisher, penchant, crimean, injecting, prakash,
# Nearest to brother: ferdinando, apparel, indulge, widow, paladins, karnataka, haihowak, averted,
# Nearest to governor: corpses, centerline, locations, steamy, conservatively, prevailing, michiel, gunung,
# Nearest to primarily: revivals, time, suitcases, aps, magnet, hannity, bloemfontein, aas,
# Nearest to resources: hideo, coast, derivations, fictions, grandparents, lords, topple, brocklin,
# Nearest to quite: sunshine, breslau, industrialization, salic, blizzard, bibl, jeannie, leftmost,
# Nearest to hit: hinder, sheikh, streaming, zarathustra, encomium, limits, spain, emitted,
# Nearest to gold: breaking, squarepants, discussions, fallingwater, ochs, strictly, houllier, shipments,
# Nearest to consists: changed, assiniboine, maji, faces, darkening, irritation, normally, probability,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6761 0.0394 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6638 0.0390 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6234 0.0385 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.5864 0.0381 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6371 0.0386 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6238 0.0385 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.5835 0.0284 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5357 0.0387 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.4950 0.0384 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5173 0.0391 sec/batch
# Nearest to one: six, philanthropist, zero, five, eight, d, seven, mathematician,
# Nearest to about: covert, harmonization, overthrow, federer, displayed, image, ouagadougou, clique,
# Nearest to with: bcd, faithless, guppies, unnecessarily, beekeepers, schreiber, odowska, spars,
# Nearest to will: don, disenchanted, purport, redoutable, devices, technique, decoration, pelle,
# Nearest to and: imperfect, earliest, phenomena, masturbation, enchanted, alluded, readability, sacrifices,
# Nearest to than: detonation, thieves, patriarchal, invited, suppressor, dysfunction, anthrax, gorham,
# Nearest to it: settings, either, something, fitted, ql, a, consonantal, peacock,
# Nearest to they: parked, hy, penchant, injecting, scapegoats, fisher, anthemius, characteristics,
# Nearest to brother: ferdinando, apparel, widow, indulge, averted, thanking, tracy, hier,
# Nearest to governor: corpses, centerline, michiel, steamy, president, american, locations, manna,
# Nearest to primarily: suitcases, revivals, time, magnet, aps, aas, bloemfontein, hannity,
# Nearest to resources: hideo, brocklin, derivations, coast, fictions, topple, grandparents, sand,
# Nearest to quite: salic, breslau, sunshine, simplistic, leftmost, blizzard, industrialization, jeannie,
# Nearest to hit: hinder, sheikh, zarathustra, encomium, ration, streaming, vasco, limits,
# Nearest to gold: breaking, squarepants, ochs, houllier, fallingwater, strictly, discussions, dine,
# Nearest to consists: changed, assiniboine, maji, darkening, normally, medallions, probability, irritation,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4748 0.0387 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4954 0.0391 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4547 0.0386 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5231 0.0400 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4660 0.0376 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4678 0.0382 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4957 0.0391 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4090 0.0394 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4316 0.0388 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4351 0.0391 sec/batch
# Nearest to one: six, zero, philanthropist, five, mes, two, moritz, three,
# Nearest to about: covert, harmonization, displayed, image, federer, suitcases, runic, cilicia,
# Nearest to with: bcd, faithless, guppies, spars, beekeepers, refraining, unnecessarily, inconsistent,
# Nearest to will: disenchanted, purport, don, redoutable, warhammer, drawback, devices, bullseye,
# Nearest to and: earliest, imperfect, masturbation, readability, alluded, seclusion, sacrifices, flowchart,
# Nearest to than: detonation, thieves, anthrax, patriarchal, suppressor, foresaw, gorham, breathes,
# Nearest to it: settings, either, something, ql, peacock, marry, dbms, a,
# Nearest to they: parked, scapegoats, injecting, penchant, booby, topeka, hy, arrangers,
# Nearest to brother: ferdinando, apparel, widow, indulge, son, thanking, hier, averted,
# Nearest to governor: corpses, president, steamy, michiel, centerline, gunung, appalachian, manna,
# Nearest to primarily: suitcases, magnet, time, revivals, aas, aps, hannity, bloemfontein,
# Nearest to resources: hideo, derivations, brocklin, ethnographers, forest, coast, grid, hypro,
# Nearest to quite: salic, sunshine, simplistic, blizzard, breslau, industrialization, anomie, leftmost,
# Nearest to hit: zarathustra, hinder, streaming, encomium, ration, sheikh, perugia, vasco,
# Nearest to gold: breaking, squarepants, fallingwater, dine, houllier, ochs, coronations, shipments,
# Nearest to consists: changed, vector, assiniboine, normally, maji, medallions, darkening, irritation,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4481 0.0396 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4217 0.0380 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4403 0.0389 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.4033 0.0386 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4274 0.0380 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4467 0.0385 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3890 0.0386 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3711 0.0391 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4155 0.0391 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3705 0.0392 sec/batch
# Nearest to one: six, zero, philanthropist, five, two, seven, three, moritz,
# Nearest to about: harmonization, runic, image, displayed, covert, suitcases, federer, clique,
# Nearest to with: bcd, beekeepers, faithless, odowska, taipei, refraining, seasoning, guppies,
# Nearest to will: disenchanted, purport, don, redoutable, drawback, coincident, warhammer, bullseye,
# Nearest to and: drawn, readability, earliest, imperfect, masturbation, sacrifices, flowchart, seclusion,
# Nearest to than: detonation, anthrax, patriarchal, thieves, suppressor, breathes, gorham, foresaw,
# Nearest to it: settings, something, either, dbms, a, marry, consonantal, peacock,
# Nearest to they: parked, scapegoats, topeka, arrangers, penchant, injecting, booby, shipmates,
# Nearest to brother: ferdinando, son, widow, indulge, apparel, averted, napoleon, divorced,
# Nearest to governor: president, corpses, michiel, steamy, gunung, centerline, appalachian, toro,
# Nearest to primarily: suitcases, time, magnet, revivals, aps, aas, hannity, bloemfontein,
# Nearest to resources: hideo, derivations, ethnographers, forest, grid, hypro, moderate, brocklin,
# Nearest to quite: simplistic, salic, sunshine, anomie, leftmost, breslau, jeannie, vegetation,
# Nearest to hit: zarathustra, streaming, hinder, encomium, hashim, ration, blackhawks, songwriters,
# Nearest to gold: breaking, squarepants, houllier, dine, fallingwater, ochs, ruggiero, shipments,
# Nearest to consists: maji, assiniboine, normally, changed, medallions, darkening, vector, faces,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3599 0.0398 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3843 0.0387 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3324 0.0386 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3698 0.0386 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3943 0.0393 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3652 0.0386 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3938 0.0404 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3962 0.0386 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3145 0.0385 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3179 0.0388 sec/batch
# Nearest to one: six, zero, two, five, three, philanthropist, seven, eight,
# Nearest to about: harmonization, runic, also, image, diverged, displayed, centimeters, blanket,
# Nearest to with: bcd, beekeepers, odowska, seasoning, unnecessarily, faithless, regionally, restlessness,
# Nearest to will: disenchanted, don, purport, redoutable, drawback, glow, wiped, pelle,
# Nearest to and: drawn, readability, masturbation, imperfect, earliest, mundane, these, migrated,
# Nearest to than: detonation, suppressor, thieves, patriarchal, anthrax, breathes, gorham, markan,
# Nearest to it: either, settings, a, something, dbms, consonantal, marry, observance,
# Nearest to they: scapegoats, parked, arrangers, topeka, injecting, cultivate, penchant, greeneville,
# Nearest to brother: ferdinando, son, widow, napoleon, thanking, indulge, apparel, lucien,
# Nearest to governor: president, gunung, michiel, resignation, office, offices, steamy, toro,
# Nearest to primarily: magnet, suitcases, time, aps, revivals, aas, hannity, whiteness,
# Nearest to resources: ethnographers, derivations, forest, hypro, hideo, slums, brocklin, grid,
# Nearest to quite: simplistic, salic, sunshine, leftmost, anomie, pregnancy, jeannie, licensee,
# Nearest to hit: zarathustra, streaming, hinder, hashim, grass, topped, songwriters, encomium,
# Nearest to gold: breaking, squarepants, houllier, dine, shipments, fallingwater, ruggiero, wren,
# Nearest to consists: changed, normally, maji, assiniboine, medallions, frankness, darkening, faces,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3399 0.0404 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2695 0.0388 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3808 0.0402 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3922 0.0383 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3902 0.0390 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2910 0.0401 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.2810 0.0385 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3331 0.0397 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2242 0.0393 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.3019 0.0393 sec/batch
# Nearest to one: six, zero, two, three, five, seven, philanthropist, eight,
# Nearest to about: harmonization, runic, yakuza, oscilloscope, also, federer, ouagadougou, contrabassoon,
# Nearest to with: seasoning, odowska, faithless, beekeepers, bcd, regionally, guernica, padding,
# Nearest to will: disenchanted, don, purport, redoutable, glow, coincident, warhammer, hexane,
# Nearest to and: readability, drawn, phenomena, masturbation, plaine, mundane, rumford, discourage,
# Nearest to than: detonation, suppressor, thieves, gorham, inman, markan, anthrax, patriarchal,
# Nearest to it: either, a, settings, dbms, something, consonantal, intersections, peacock,
# Nearest to they: scapegoats, arrangers, injecting, parked, penchant, cultivate, greeneville, topeka,
# Nearest to brother: ferdinando, son, widow, apparel, indulge, hier, lucien, thanking,
# Nearest to governor: president, michiel, resignation, gunung, office, toro, american, steamy,
# Nearest to primarily: suitcases, magnet, time, aas, aps, revivals, hannity, incurring,
# Nearest to resources: ethnographers, hypro, forest, derivations, slums, hideo, moderate, extremes,
# Nearest to quite: simplistic, salic, anomie, sunshine, jeannie, licensee, leftmost, pregnancy,
# Nearest to hit: zarathustra, streaming, songwriters, topped, debut, hinder, hashim, encomium,
# Nearest to gold: breaking, squarepants, houllier, shipments, dine, wren, fallingwater, ruggiero,
# Nearest to consists: normally, changed, assiniboine, medallions, maji, darkening, frankness, faces,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3012 0.0398 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2884 0.0397 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3354 0.0174 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2553 0.0387 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2211 0.0393 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2121 0.0402 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.1988 0.0382 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2357 0.0389 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2381 0.0381 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1628 0.0377 sec/batch
# Nearest to one: six, zero, five, three, two, seven, philanthropist, eight,
# Nearest to about: harmonization, runic, also, diverged, yakuza, centimeters, oscilloscope, established,
# Nearest to with: seasoning, faithless, odowska, padding, spotted, beekeepers, kampen, bcd,
# Nearest to will: disenchanted, don, purport, redoutable, wiped, shall, capricious, sarcastically,
# Nearest to and: readability, plaine, toba, drawn, juntas, earliest, savoury, migrated,
# Nearest to than: detonation, suppressor, thieves, gorham, inman, anthrax, imbolc, markan,
# Nearest to it: either, dbms, a, consonantal, settings, something, cliffordadams, gridiron,
# Nearest to they: injecting, scapegoats, arrangers, cultivate, parked, penchant, femininity, greeneville,
# Nearest to brother: ferdinando, son, widow, indulge, hier, lala, divorced, thanking,
# Nearest to governor: michiel, president, gunung, resignation, office, offices, toro, gayoom,
# Nearest to primarily: suitcases, magnet, aas, time, hannity, aps, revivals, whiteness,
# Nearest to resources: ethnographers, hypro, derivations, forest, slums, moderate, manos, msdn,
# Nearest to quite: simplistic, sunshine, licensee, salic, anomie, jeannie, charnley, leftmost,
# Nearest to hit: zarathustra, streaming, topped, hashim, songwriters, debut, hinder, emitted,
# Nearest to gold: breaking, squarepants, dine, houllier, shipments, ruggiero, wren, olympics,
# Nearest to consists: normally, maji, medallions, changed, darkening, assiniboine, frankness, vector,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2142 0.0400 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2464 0.0394 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2398 0.0388 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1528 0.0399 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1604 0.0389 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1381 0.0395 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1651 0.0381 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1884 0.0382 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1960 0.0399 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1842 0.0384 sec/batch
# Nearest to one: zero, six, five, three, two, seven, four, eight,
# Nearest to about: harmonization, runic, contrabassoon, oscilloscope, yakuza, diverged, ouagadougou, centimeters,
# Nearest to with: odowska, bcd, seasoning, faithless, kampen, coupled, padding, unnecessarily,
# Nearest to will: disenchanted, don, shall, purport, grievous, pelle, glow, redoutable,
# Nearest to and: readability, imperfect, masturbation, plaine, anthropogenic, parlance, savoury, diseases,
# Nearest to than: detonation, suppressor, nhs, inman, imbolc, anthrax, markan, numerator,
# Nearest to it: either, a, dbms, something, consonantal, settings, leftmost, summarize,
# Nearest to they: scapegoats, injecting, arrangers, femininity, rodeo, booby, parked, cultivate,
# Nearest to brother: son, ferdinando, widow, lucien, lala, hier, divorced, schell,
# Nearest to governor: michiel, president, gunung, resignation, office, offices, cabinet, caretaker,
# Nearest to primarily: suitcases, magnet, aas, aps, revivals, classify, hannity, incurring,
# Nearest to resources: ethnographers, hypro, slums, forest, derivations, msdn, manos, hideo,
# Nearest to quite: simplistic, sunshine, anomie, licensee, salic, leftmost, mean, charnley,
# Nearest to hit: streaming, zarathustra, topped, songwriters, hashim, debut, emitted, blackhawks,
# Nearest to gold: breaking, squarepants, houllier, dine, wren, ruggiero, olympics, leumi,
# Nearest to consists: normally, medallions, maji, assiniboine, faces, changed, vector, darkening,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1651 0.0401 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2335 0.0406 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1899 0.0401 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1317 0.0396 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1839 0.0384 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1912 0.0386 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1933 0.0395 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1401 0.0404 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1250 0.0395 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1744 0.0391 sec/batch
# Nearest to one: six, zero, five, two, three, seven, four, eight,
# Nearest to about: harmonization, runic, what, oscilloscope, contrabassoon, pedophilia, centimeters, views,
# Nearest to with: odowska, taxicab, coupled, seasoning, kampen, unnecessarily, faithless, rode,
# Nearest to will: disenchanted, don, shall, glow, purport, cofinal, pelle, redoutable,
# Nearest to and: readability, imperfect, masturbation, drawn, petula, subsidies, encroaching, outset,
# Nearest to than: detonation, suppressor, imbolc, inman, nhs, numerator, bute, patriarchal,
# Nearest to it: dbms, either, a, consonantal, something, gridiron, settings, cliffordadams,
# Nearest to they: arrangers, scapegoats, injecting, rodeo, penchant, cultivate, femininity, redirecting,
# Nearest to brother: son, ferdinando, widow, lucien, hier, schell, lala, apparel,
# Nearest to governor: president, office, resignation, michiel, gunung, cabinet, caretaker, members,
# Nearest to primarily: suitcases, classify, magnet, incurring, aps, aas, hannity, revivals,
# Nearest to resources: hypro, ethnographers, slums, forest, derivations, msdn, manos, sociocultural,
# Nearest to quite: simplistic, sunshine, anomie, salic, mean, charnley, leftmost, orosius,
# Nearest to hit: streaming, zarathustra, topped, hashim, emitted, songwriters, selling, debut,
# Nearest to gold: breaking, squarepants, dine, shipments, wren, houllier, ruggiero, olympics,
# Nearest to consists: normally, maji, medallions, frankness, assiniboine, changed, maestra, darkening,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2020 0.0390 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1736 0.0394 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1863 0.0387 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1641 0.0400 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1678 0.0396 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1360 0.0390 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1650 0.0391 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1320 0.0394 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.2043 0.0398 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2173 0.0383 sec/batch
# Nearest to one: six, zero, five, two, three, seven, eight, four,
# Nearest to about: harmonization, what, yakuza, views, oscilloscope, contrabassoon, ouagadougou, kwh,
# Nearest to with: odowska, kampen, stendhal, guernica, faithless, steen, rode, taxicab,
# Nearest to will: don, shall, disenchanted, glow, grievous, capricious, wiped, pelle,
# Nearest to and: rodney, hartmann, drawn, the, plaine, outset, oversee, readability,
# Nearest to than: detonation, suppressor, nhs, numerator, bute, imbolc, portugu, inman,
# Nearest to it: a, either, something, marry, dbms, consonantal, peacock, smite,
# Nearest to they: scapegoats, arrangers, rodeo, cultivate, penchant, their, would, redirecting,
# Nearest to brother: son, ferdinando, widow, lucien, divorced, lala, marooned, indulge,
# Nearest to governor: office, michiel, president, resignation, gunung, offices, caretaker, cabinet,
# Nearest to primarily: magnet, classify, suitcases, incurring, aas, aps, dignitaries, whiteness,
# Nearest to resources: hypro, ethnographers, slums, forest, derivations, msdn, manos, extensive,
# Nearest to quite: simplistic, sunshine, charnley, seconda, anomie, salic, fantastical, mean,
# Nearest to hit: zarathustra, topped, streaming, debut, hashim, selling, songwriters, blackhawks,
# Nearest to gold: squarepants, breaking, dine, shipments, houllier, olympics, wren, ruggiero,
# Nearest to consists: normally, maji, frankness, medallions, assiniboine, maestra, changed, pueblos,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2246 0.0392 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1207 0.0399 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1404 0.0395 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1158 0.0387 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0473 0.0384 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1220 0.0405 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1558 0.0394 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1225 0.0394 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1614 0.0061 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1237 0.0404 sec/batch
# Nearest to one: six, zero, five, two, three, seven, four, eight,
# Nearest to about: harmonization, yakuza, oscilloscope, kwh, what, ouagadougou, views, contrabassoon,
# Nearest to with: odowska, kampen, spotted, beekeepers, faithless, seasoning, unnecessarily, regionally,
# Nearest to will: don, shall, disenchanted, grievous, glow, pelle, purport, capricious,
# Nearest to and: readability, drawn, the, encroaching, rodney, diseases, outset, subsidies,
# Nearest to than: detonation, suppressor, nhs, numerator, inman, imbolc, bute, campo,
# Nearest to it: something, a, either, consonantal, smite, dbms, citywide, gridiron,
# Nearest to they: scapegoats, rodeo, arrangers, cultivate, everywhere, injecting, politeness, scaffolding,
# Nearest to brother: son, ferdinando, widow, lala, lucien, divorced, marooned, eloped,
# Nearest to governor: president, michiel, office, resignation, gunung, gayoom, caretaker, offices,
# Nearest to primarily: suitcases, magnet, incurring, classify, aps, aas, whiteness, ang,
# Nearest to resources: hypro, ethnographers, slums, forest, extensive, derivations, msdn, allafrica,
# Nearest to quite: simplistic, leverett, sunshine, seconda, charnley, mean, orosius, anomie,
# Nearest to hit: topped, zarathustra, debut, songwriters, selling, streaming, hashim, bokken,
# Nearest to gold: squarepants, breaking, dine, olympics, houllier, ruggiero, shipments, plotlines,
# Nearest to consists: normally, maji, frankness, medallions, changed, assiniboine, maestra, darkening,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0688 0.0401 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0787 0.0384 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0826 0.0401 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0448 0.0399 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0981 0.0391 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0381 0.0387 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.1027 0.0385 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.1067 0.0388 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1051 0.0387 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0551 0.0392 sec/batch
# Nearest to one: zero, six, five, three, two, four, seven, eight,
# Nearest to about: yakuza, harmonization, views, what, oscilloscope, kwh, centimeters, diverged,
# Nearest to with: odowska, faithless, spotted, negroids, kampen, rode, seasoning, taxicab,
# Nearest to will: shall, don, disenchanted, capricious, grievous, pelle, innards, europium,
# Nearest to and: the, readability, parlance, of, drawn, as, outset, migrated,
# Nearest to than: detonation, suppressor, nhs, inman, numerator, splitting, imbolc, markan,
# Nearest to it: a, either, something, smite, gridiron, citywide, ql, consonantal,
# Nearest to they: scapegoats, their, rodeo, injecting, them, booby, arrangers, cultivate,
# Nearest to brother: ferdinando, son, widow, lala, lucien, apparel, divorced, marooned,
# Nearest to governor: office, president, michiel, gunung, resignation, gayoom, cabinet, caucasians,
# Nearest to primarily: magnet, suitcases, classify, aps, aas, incurring, dignitaries, revivals,
# Nearest to resources: ethnographers, hypro, slums, forest, extensive, avoidance, derivations, msdn,
# Nearest to quite: simplistic, charnley, sunshine, seconda, leverett, orosius, shinogi, mean,
# Nearest to hit: topped, bokken, emitted, zarathustra, hashim, stripe, debut, blackhawks,
# Nearest to gold: squarepants, breaking, dine, houllier, ruggiero, shipments, olympics, chan,
# Nearest to consists: normally, frankness, maji, maestra, medallions, assiniboine, strictest, darkening,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0163 0.0396 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0175 0.0397 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0109 0.0393 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0458 0.0373 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0496 0.0394 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0760 0.0384 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0825 0.0395 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.0921 0.0391 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0700 0.0381 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0395 0.0390 sec/batch
# Nearest to one: six, zero, five, two, three, four, seven, eight,
# Nearest to about: yakuza, what, evidence, views, oscilloscope, centimeters, kwh, underlies,
# Nearest to with: odowska, bitters, coupled, beekeepers, regionally, taxicab, kampen, restlessness,
# Nearest to will: shall, disenchanted, don, capricious, glow, europium, pelle, grievous,
# Nearest to and: the, of, readability, parlance, as, drawn, demonstrates, diseases,
# Nearest to than: detonation, suppressor, nhs, numerator, markan, splitting, sooty, imbolc,
# Nearest to it: a, either, gridiron, consonantal, dbms, something, settings, leftmost,
# Nearest to they: scapegoats, rodeo, their, injecting, femininity, everywhere, arrangers, politeness,
# Nearest to brother: ferdinando, son, lala, marooned, widow, lucien, apparel, schell,
# Nearest to governor: office, gunung, president, michiel, gayoom, resignation, caucasians, caretaker,
# Nearest to primarily: magnet, suitcases, classify, incurring, hannity, aps, dignitaries, whiteness,
# Nearest to resources: hypro, ethnographers, slums, forest, extensive, forests, avoidance, sociocultural,
# Nearest to quite: simplistic, sunshine, charnley, orosius, seconda, anomie, leverett, shinogi,
# Nearest to hit: bokken, topped, zarathustra, stripe, blackhawks, hashim, emitted, hitting,
# Nearest to gold: squarepants, dine, breaking, ruggiero, houllier, plotlines, wren, coyote,
# Nearest to consists: normally, frankness, maji, maestra, variegated, changed, strictest, medallions,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0729 0.0400 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0881 0.0383 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0765 0.0406 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0613 0.0393 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0667 0.0389 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0430 0.0389 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0739 0.0389 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0611 0.0399 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0872 0.0389 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0844 0.0394 sec/batch
# Nearest to one: zero, six, five, two, three, seven, four, eight,
# Nearest to about: what, views, evidence, underlies, centimeters, kwh, yakuza, runic,
# Nearest to with: odowska, regionally, the, coupled, taxicab, and, faithless, restlessness,
# Nearest to will: shall, don, disenchanted, capricious, pelle, cofinal, europium, grievous,
# Nearest to and: the, of, as, drawn, filius, migrated, outset, readability,
# Nearest to than: nhs, detonation, suppressor, numerator, campo, imbolc, markan, shipwrecks,
# Nearest to it: a, either, gridiron, wrestled, marry, consonantal, something, smite,
# Nearest to they: scapegoats, their, rodeo, arrangers, cultivate, everywhere, injecting, politeness,
# Nearest to brother: son, ferdinando, lucien, schell, lala, widow, apparel, marooned,
# Nearest to governor: office, president, resignation, gunung, caucasians, michiel, cabinet, gayoom,
# Nearest to primarily: magnet, classify, suitcases, malawi, incurring, dignitaries, hannity, revivals,
# Nearest to resources: hypro, ethnographers, slums, forest, extensive, avoidance, sociocultural, forests,
# Nearest to quite: simplistic, sunshine, orosius, charnley, seconda, anomie, salic, shinogi,
# Nearest to hit: bokken, zarathustra, emitted, topped, blackhawks, hashim, stripe, hitting,
# Nearest to gold: squarepants, breaking, plotlines, dine, houllier, wren, ruggiero, djiboutian,
# Nearest to consists: normally, frankness, assiniboine, strictest, maestra, medallions, changed, maji,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0810 0.0395 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0075 0.0390 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0268 0.0396 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0369 0.0390 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0736 0.0389 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1093 0.0394 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1335 0.0392 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0448 0.0394 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0582 0.0390 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0547 0.0382 sec/batch
# Nearest to one: zero, six, five, three, four, seven, two, eight,
# Nearest to about: kwh, zero, yakuza, what, centimeters, views, mahilyow, covert,
# Nearest to with: odowska, faithless, taxicab, regionally, and, the, coupled, bitters,
# Nearest to will: shall, don, disenchanted, capricious, cofinal, pelle, glow, if,
# Nearest to and: the, of, drawn, readability, as, parlance, with, anthropogenic,
# Nearest to than: detonation, nhs, numerator, suppressor, sooty, campo, markan, shipwrecks,
# Nearest to it: a, either, gridiron, something, smite, wrestled, consonantal, peacock,
# Nearest to they: rodeo, scapegoats, everywhere, arrangers, cultivate, their, politeness, injecting,
# Nearest to brother: son, ferdinando, lucien, apparel, divorced, widow, eloped, marooned,
# Nearest to governor: office, resignation, president, michiel, gayoom, caucasians, gunung, cabinet,
# Nearest to primarily: magnet, classify, suitcases, incurring, revivals, ang, hannity, bodybuilders,
# Nearest to resources: hypro, ethnographers, slums, forest, extensive, avoidance, msdn, allafrica,
# Nearest to quite: simplistic, sunshine, seconda, charnley, orosius, shinogi, mean, redbrick,
# Nearest to hit: bokken, zarathustra, topped, blackhawks, hashim, emitted, songwriters, benitez,
# Nearest to gold: squarepants, dine, plotlines, houllier, wren, breaking, ruggiero, djiboutian,
# Nearest to consists: normally, strictest, frankness, maestra, medallions, assiniboine, changed, maji,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 4.0164 0.0397 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0235 0.0401 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0412 0.0394 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0237 0.0384 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0682 0.0395 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0464 0.0344 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0022 0.0379 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 4.0130 0.0389 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0216 0.0392 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9798 0.0397 sec/batch
# Nearest to one: zero, six, five, four, seven, three, two, eight,
# Nearest to about: what, centimeters, views, yakuza, mahilyow, diverged, kwh, evidence,
# Nearest to with: the, odowska, and, faithless, regionally, to, kb, bitters,
# Nearest to will: shall, don, disenchanted, capricious, cofinal, pelle, grievous, to,
# Nearest to and: the, of, as, parlance, with, readability, drawn, antlia,
# Nearest to than: nhs, numerator, detonation, suppressor, more, shipwrecks, cpsu, agglutinative,
# Nearest to it: a, either, peacock, something, smite, consonantal, citywide, fatou,
# Nearest to they: scapegoats, everywhere, rodeo, their, cultivate, them, politeness, topeka,
# Nearest to brother: ferdinando, son, eloped, divorced, arran, widow, till, marooned,
# Nearest to governor: resignation, gayoom, office, caucasians, michiel, president, linearity, offices,
# Nearest to primarily: magnet, suitcases, classify, aps, bodybuilders, ang, incurring, hannity,
# Nearest to resources: hypro, ethnographers, slums, forest, extensive, avoidance, allafrica, msdn,
# Nearest to quite: simplistic, sunshine, leverett, orosius, charnley, shinogi, redbrick, seconda,
# Nearest to hit: bokken, zarathustra, topped, emitted, songwriters, hashim, merengue, hitting,
# Nearest to gold: squarepants, dine, plotlines, breaking, ruggiero, houllier, chan, djiboutian,
# Nearest to consists: normally, strictest, frankness, maji, maestra, assiniboine, variegated, thysanoessa,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 4.0048 0.0406 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9469 0.0383 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0289 0.0395 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0273 0.0388 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0146 0.0392 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0086 0.0387 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9221 0.0391 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9499 0.0394 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9434 0.0398 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9679 0.0391 sec/batch
# Nearest to one: zero, six, five, four, three, seven, two, eight,
# Nearest to about: what, mahilyow, centimeters, zero, kwh, age, diverged, covert,
# Nearest to with: the, and, to, regionally, in, faithless, odowska, only,
# Nearest to will: shall, don, disenchanted, to, capricious, europium, grievous, pelle,
# Nearest to and: the, of, are, parlance, with, as, readability, stakeholders,
# Nearest to than: nhs, detonation, suppressor, numerator, more, will, splitting, markan,
# Nearest to it: a, either, citywide, fatou, gridiron, smite, has, ql,
# Nearest to they: rodeo, their, scapegoats, everywhere, them, cultivate, injecting, arrangers,
# Nearest to brother: ferdinando, son, schell, marooned, eloped, divorced, lala, lucien,
# Nearest to governor: resignation, office, gayoom, caucasians, michiel, offices, president, linearity,
# Nearest to primarily: magnet, suitcases, classify, aps, malawi, ang, bodybuilders, hannity,
# Nearest to resources: ethnographers, hypro, slums, forest, extensive, avoidance, msdn, forests,
# Nearest to quite: simplistic, sunshine, orosius, seconda, shinogi, anomie, leverett, redbrick,
# Nearest to hit: hitting, bokken, zarathustra, topped, pitchers, blackhawks, stripe, hashim,
# Nearest to gold: plotlines, squarepants, dine, djiboutian, breaking, ruggiero, prototyped, houllier,
# Nearest to consists: normally, strictest, maestra, variegated, thysanoessa, frankness, podolsky, assiniboine,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9900 0.0403 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9966 0.0386 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 4.0086 0.0396 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0330 0.0392 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 3.9914 0.0376 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9463 0.0385 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 4.0038 0.0402 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9822 0.0389 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9966 0.0387 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9886 0.0395 sec/batch
# Nearest to one: zero, six, five, four, seven, three, nine, eight,
# Nearest to about: mahilyow, what, age, zero, evidence, kwh, views, contrabassoon,
# Nearest to with: the, and, to, in, odowska, regionally, faithless, only,
# Nearest to will: shall, don, to, capricious, disenchanted, cofinal, activates, if,
# Nearest to and: the, of, with, as, parlance, are, in, at,
# Nearest to than: nhs, numerator, detonation, suppressor, more, will, samurai, agglutinative,
# Nearest to it: a, either, citywide, being, smite, fatou, consonantal, peacock,
# Nearest to they: rodeo, everywhere, arrangers, their, scapegoats, shipmates, them, azo,
# Nearest to brother: ferdinando, son, schell, marooned, incumbents, lucien, till, eloped,
# Nearest to governor: resignation, michiel, gayoom, office, caucasians, offices, president, linearity,
# Nearest to primarily: classify, magnet, suitcases, aps, malawi, hannity, bodybuilders, revivals,
# Nearest to resources: ethnographers, hypro, slums, forest, extensive, avoidance, msdn, extremes,
# Nearest to quite: simplistic, orosius, sunshine, mean, anomie, seconda, leverett, redbrick,
# Nearest to hit: zarathustra, bokken, hitting, topped, merengue, hashim, stripe, emitted,
# Nearest to gold: djiboutian, plotlines, squarepants, ruggiero, dine, wren, houllier, medal,
# Nearest to consists: normally, strictest, thysanoessa, variegated, frankness, maestra, podolsky, assiniboine,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0068 0.0403 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9593 0.0396 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 4.0019 0.0377 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9589 0.0398 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0211 0.0398 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9953 0.0388 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 4.0152 0.0392 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9734 0.0384 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9696 0.0386 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0113 0.0388 sec/batch
# Nearest to one: zero, six, five, seven, four, three, eight, two,
# Nearest to about: mahilyow, kwh, zero, age, covert, centimeters, evidence, what,
# Nearest to with: the, and, in, to, odowska, coupled, nanpa, only,
# Nearest to will: shall, don, capricious, disenchanted, to, if, cofinal, congruence,
# Nearest to and: of, the, with, as, in, are, stakeholders, foreign,
# Nearest to than: nhs, numerator, more, suppressor, detonation, markan, are, will,
# Nearest to it: a, either, citywide, being, fatou, consonantal, smite, peacock,
# Nearest to they: their, everywhere, scapegoats, rodeo, cultivate, them, politeness, orser,
# Nearest to brother: ferdinando, son, schell, marooned, lucien, divorced, arran, incumbents,
# Nearest to governor: michiel, office, resignation, gayoom, offices, caucasians, linearity, gunung,
# Nearest to primarily: classify, magnet, malawi, suitcases, aps, ang, bodybuilders, incurring,
# Nearest to resources: hypro, ethnographers, slums, extensive, avoidance, forest, forests, hydropower,
# Nearest to quite: simplistic, seconda, orosius, mean, sunshine, anomie, shotgun, redbrick,
# Nearest to hit: zarathustra, bokken, hitting, hashim, topped, merengue, pitchers, songwriters,
# Nearest to gold: djiboutian, plotlines, dine, squarepants, polishing, silver, wren, coin,
# ...
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.8537 0.0401 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8761 0.0390 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8091 0.0383 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8731 0.0391 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.9187 0.0381 sec/batch
# Nearest to one: four, seven, five, nine, six, three, eight, zero,
# Nearest to about: mahilyow, age, skeptical, zero, what, reported, kwh, that,
# Nearest to with: and, the, to, in, a, only, as, of,
# Nearest to will: shall, if, than, swirled, to, soe, capricious, activates,
# Nearest to and: of, the, in, with, as, a, are, by,
# Nearest to than: more, are, less, however, generally, will, detail, tend,
# Nearest to it: that, a, is, was, has, being, for, the,
# Nearest to they: their, them, were, would, are, everywhere, native, have,
# Nearest to brother: ferdinando, son, father, schell, empresses, karajan, governess, shechem,
# Nearest to governor: linearity, gayoom, ayub, appalachian, michiel, lieutenant, resignation, administrators,
# Nearest to primarily: classify, compared, bodybuilders, anarchic, prescribing, magnet, contextual, abridgment,
# Nearest to resources: ethnographers, hydropower, extensive, slums, avoidance, pastures, hypro, extremes,
# Nearest to quite: shotgun, seconda, redbrick, orosius, populist, sunshine, hesitant, unintelligible,
# Nearest to hit: hitting, hits, songwriters, pitchers, bunt, bring, rbi, merengue,
# Nearest to gold: silver, medal, hbox, coin, tarquin, djiboutian, antimony, allotropes,
# Nearest to consists: normally, strictest, podolsky, thysanoessa, wright, labial, seating, decorated,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8264 0.0399 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8505 0.0391 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8806 0.0393 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8413 0.0379 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8733 0.0385 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8606 0.0397 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8561 0.0392 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8724 0.0392 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8975 0.0385 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8472 0.0375 sec/batch
# Nearest to one: seven, six, five, four, nine, three, zero, two,
# Nearest to about: zero, mahilyow, age, kwh, what, skeptical, reported, that,
# Nearest to with: and, the, to, a, in, as, of, between,
# Nearest to will: shall, if, swirled, than, lying, capricious, soe, cofinal,
# Nearest to and: of, the, in, with, as, are, a, by,
# Nearest to than: more, are, less, however, generally, of, detail, will,
# Nearest to it: that, a, was, is, being, has, as, the,
# Nearest to they: them, their, were, would, everywhere, native, did, analogical,
# Nearest to brother: ferdinando, son, father, schell, empresses, karajan, shechem, governess,
# Nearest to governor: linearity, gayoom, holders, michiel, resignation, lieutenant, ayub, appalachian,
# Nearest to primarily: classify, compared, arabism, prescribing, bodybuilders, anarchic, abridgment, reconnaissance,
# Nearest to resources: hydropower, ethnographers, pastures, extremes, extensive, slums, hypro, avoidance,
# Nearest to quite: shotgun, orosius, redbrick, nabataean, seconda, populist, categorized, salic,
# Nearest to hit: hitting, hits, merengue, zarathustra, mixes, songwriters, bunt, rbi,
# Nearest to gold: silver, hbox, medal, coin, tarquin, precious, djiboutian, antimony,
# Nearest to consists: normally, strictest, wright, podolsky, judicial, thysanoessa, ironic, decorated,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8735 0.0401 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8496 0.0382 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8312 0.0388 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8242 0.0386 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.9044 0.0395 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8400 0.0390 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9588 0.0396 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8917 0.0399 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9278 0.0390 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8346 0.0388 sec/batch
# Nearest to one: four, five, seven, six, zero, three, nine, two,
# Nearest to about: zero, age, kwh, mahilyow, reported, that, what, centimeters,
# Nearest to with: and, to, the, a, in, as, of, s,
# Nearest to will: shall, if, capricious, lying, swirled, soe, messenger, commonalities,
# Nearest to and: of, the, in, with, as, are, a, by,
# Nearest to than: more, are, less, generally, however, of, tend, most,
# Nearest to it: that, a, was, has, is, be, the, being,
# Nearest to they: them, their, were, would, did, everywhere, are, native,
# Nearest to brother: ferdinando, son, father, schell, empresses, karajan, shechem, arran,
# Nearest to governor: linearity, gayoom, michiel, holders, ayub, appalachian, lieutenant, resignation,
# Nearest to primarily: classify, compared, arabism, anarchic, bodybuilders, prescribing, contextual, aps,
# Nearest to resources: hydropower, pastures, extremes, ethnographers, extensive, sand, slums, hypro,
# Nearest to quite: shotgun, redbrick, orosius, extremely, seconda, populist, shrink, fluency,
# Nearest to hit: hitting, hits, merengue, zarathustra, songwriters, mixes, orcas, rbi,
# Nearest to gold: silver, hbox, medal, coin, tarquin, precious, djiboutian, allotropes,
# Nearest to consists: normally, strictest, wright, ironic, podolsky, thysanoessa, labial, consisting,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7863 0.0401 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8524 0.0393 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7678 0.0384 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8593 0.0391 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8194 0.0395 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8303 0.0392 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8912 0.0191 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8335 0.0392 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8412 0.0400 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8573 0.0387 sec/batch
# Nearest to one: four, six, five, seven, eight, nine, three, two,
# Nearest to about: zero, age, mahilyow, kwh, that, what, skeptical, palmyra,
# Nearest to with: and, to, the, a, in, as, of, by,
# Nearest to will: shall, if, capricious, soe, swirled, commonalities, lying, cofinal,
# Nearest to and: of, the, in, as, with, are, a, by,
# Nearest to than: more, are, less, generally, however, tend, robustness, both,
# Nearest to it: that, was, a, the, be, not, being, is,
# Nearest to they: them, their, were, would, are, everywhere, have, did,
# Nearest to brother: ferdinando, son, father, empresses, arran, shechem, rightful, disposition,
# Nearest to governor: linearity, gayoom, lieutenant, michiel, holders, administrators, ayub, appalachian,
# Nearest to primarily: classify, compared, anarchic, arabism, contextual, prescribing, bodybuilders, aps,
# Nearest to resources: hydropower, pastures, ethnographers, extremes, slums, sand, extensive, hypro,
# Nearest to quite: redbrick, extremely, orosius, shotgun, seconda, nabataean, fluency, hesitant,
# Nearest to hit: hitting, hits, mixes, merengue, songwriters, zarathustra, bokken, orcas,
# Nearest to gold: silver, medal, hbox, coin, tarquin, precious, allotropes, djiboutian,
# Nearest to consists: normally, strictest, labial, ironic, wright, consisting, podolsky, thysanoessa,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8500 0.0395 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8255 0.0391 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8176 0.0398 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.8040 0.0380 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8475 0.0386 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8553 0.0393 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8669 0.0389 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7348 0.0401 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8088 0.0392 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.8024 0.0396 sec/batch
# Nearest to one: four, five, seven, six, zero, three, nine, eight,
# Nearest to about: zero, mahilyow, kwh, age, reported, what, skeptical, centimeters,
# Nearest to with: and, the, to, in, a, as, of, only,
# Nearest to will: shall, if, than, capricious, to, soe, swirled, lying,
# Nearest to and: of, the, in, with, as, are, a, by,
# Nearest to than: more, are, less, generally, however, of, will, and,
# Nearest to it: that, a, has, is, was, be, the, as,
# Nearest to they: them, their, were, would, are, have, very, native,
# Nearest to brother: ferdinando, son, father, empresses, schell, arran, shechem, karajan,
# Nearest to governor: linearity, gayoom, holders, administrators, lieutenant, appalachian, sir, michiel,
# Nearest to primarily: compared, classify, bodybuilders, anarchic, arabism, aps, prescribing, useful,
# Nearest to resources: pastures, hydropower, ethnographers, extremes, hypro, extensive, slums, sand,
# Nearest to quite: extremely, shotgun, nabataean, orosius, redbrick, seconda, hesitant, fluency,
# Nearest to hit: hitting, hits, bunt, merengue, bring, pitchers, rbi, mixes,
# Nearest to gold: silver, medal, hbox, coin, tarquin, allotropes, precious, djiboutian,
# Nearest to consists: normally, strictest, consisting, wright, labial, ironic, of, podolsky,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7683 0.0387 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8224 0.0381 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8554 0.0380 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8322 0.0385 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8426 0.0380 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8822 0.0390 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8238 0.0383 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8189 0.0384 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8142 0.0388 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8536 0.0392 sec/batch
# Nearest to one: four, five, six, seven, zero, eight, nine, three,
# Nearest to about: zero, mahilyow, age, reported, that, skeptical, kwh, covert,
# Nearest to with: and, the, to, in, a, as, of, between,
# Nearest to will: shall, if, capricious, to, than, swirled, soe, conforms,
# Nearest to and: of, the, in, with, as, are, a, by,
# Nearest to than: more, are, less, however, generally, of, tend, most,
# Nearest to it: that, is, a, be, as, has, was, for,
# Nearest to they: them, their, were, are, would, have, very, did,
# Nearest to brother: ferdinando, son, father, schell, empresses, arran, rightful, shechem,
# Nearest to governor: linearity, gayoom, holders, appalachian, lieutenant, michiel, sir, resignation,
# Nearest to primarily: classify, compared, bodybuilders, anarchic, arabism, prescribing, contextual, abridgment,
# Nearest to resources: pastures, hydropower, ethnographers, extremes, sand, hypro, slums, avoidance,
# Nearest to quite: extremely, nabataean, shotgun, orosius, redbrick, hesitant, unintelligible, seconda,
# Nearest to hit: hitting, hits, merengue, mixes, bunt, songwriters, orcas, compressibility,
# Nearest to gold: silver, medal, hbox, coin, tarquin, djiboutian, allotropes, platinum,
# Nearest to consists: normally, strictest, consisting, wright, ironic, judicial, labial, seating,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8713 0.0398 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8104 0.0393 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8205 0.0390 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8415 0.0379 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8591 0.0387 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8300 0.0393 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8076 0.0407 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8371 0.0391 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8271 0.0389 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8196 0.0386 sec/batch
# Nearest to one: four, five, seven, six, three, zero, nine, eight,
# Nearest to about: zero, age, mahilyow, reported, journalism, kwh, that, skeptical,
# Nearest to with: and, to, the, in, a, as, of, between,
# Nearest to will: if, shall, to, cofinal, than, capricious, swirled, conforms,
# Nearest to and: of, the, in, with, as, are, a, by,
# Nearest to than: more, are, less, generally, however, tend, larger, although,
# Nearest to it: that, is, a, be, has, for, as, was,
# Nearest to they: them, their, were, would, are, have, native, did,
# Nearest to brother: ferdinando, son, father, schell, empresses, arran, rightful, shechem,
# Nearest to governor: linearity, gayoom, holders, sir, michiel, lieutenant, appalachian, resignation,
# Nearest to primarily: compared, classify, bodybuilders, prescribing, anarchic, arabism, useful, contextual,
# Nearest to resources: pastures, hydropower, ethnographers, extremes, sand, avoidance, extensive, hypro,
# Nearest to quite: extremely, shotgun, nabataean, orosius, hesitant, redbrick, unintelligible, shinogi,
# Nearest to hit: hitting, hits, mixes, merengue, bunt, rbi, zarathustra, compressibility,
# Nearest to gold: silver, hbox, medal, coin, tarquin, precious, djiboutian, platinum,
# Nearest to consists: normally, consisting, strictest, wright, of, ironic, labial, representation,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8751 0.0390 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8184 0.0394 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9095 0.0377 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9108 0.0394 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8826 0.0388 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8389 0.0384 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.8138 0.0389 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8077 0.0392 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7623 0.0398 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8849 0.0399 sec/batch
# Nearest to one: four, seven, six, nine, five, eight, two, three,
# Nearest to about: age, zero, mahilyow, that, journalism, reported, kwh, skeptical,
# Nearest to with: and, to, the, a, in, as, s, between,
# Nearest to will: if, shall, cofinal, soe, lying, to, capricious, commodores,
# Nearest to and: of, the, in, with, as, a, by, are,
# Nearest to than: more, less, are, generally, however, tend, larger, most,
# Nearest to it: that, a, was, be, is, for, not, has,
# Nearest to they: them, their, were, would, are, native, very, have,
# Nearest to brother: ferdinando, son, father, schell, rightful, empresses, karajan, shechem,
# Nearest to governor: linearity, gayoom, sir, lieutenant, holders, michiel, resignation, kbe,
# Nearest to primarily: compared, classify, bodybuilders, prescribing, aps, useful, contextual, arabism,
# Nearest to resources: pastures, hydropower, extremes, ethnographers, sand, extensive, slums, hypro,
# Nearest to quite: extremely, shotgun, redbrick, unintelligible, nabataean, populist, hesitant, orosius,
# Nearest to hit: hits, hitting, merengue, mixes, sampled, orcas, songwriters, bunt,
# Nearest to gold: silver, hbox, medal, coin, precious, djiboutian, tarquin, platinum,
# Nearest to consists: normally, strictest, consisting, wright, of, each, judicial, seating,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8607 0.0400 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8121 0.0390 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
